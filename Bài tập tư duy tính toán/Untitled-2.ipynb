# %% [markdown]
# Bai 1 : In ra dong "Hello word"

# %%
print("Hello world" , "Hello world", sep=' ')
# Out:
# Hello word Hello word

# %%
print("Hello world!")
print("Hello world!")
# Out:
# Hello world!
# Hello world!
