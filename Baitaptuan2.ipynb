# %% [markdown]
# BIỂU THỨC TOÁN TỬ NHẬP XUẤT DỮ LIỆU

# %% [markdown]
# W2A1

# %%
print("Hello World!")
# Out:
# Hello World!
# Hello World!

# %% [markdown]
# W2A2

# %%
name = input("Nhap ten cua ban: ")
print("Hello", name + "!", sep = " ")
# Out:
# Hello Anh!

# %% [markdown]
# W2A3

# %%
a, b = map(input("nhap:").split())
n = a + b
print("Tong:", n)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 a, b = map(input("nhap:").split())
#       2 n = a + b
#       3 print("Tong:", n)
#
# TypeError: map() must have at least two arguments.
